# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#The-code-below-is-an-implementation-of-the-Node-class-for-which-of-the-following-linked-lists?" data-toc-modified-id="The-code-below-is-an-implementation-of-the-Node-class-for-which-of-the-following-linked-lists?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>The code below is an implementation of the Node class for which of the following linked lists?</a></span></li><li><span><a href="#What-is-the-output-of-the-following-code?" data-toc-modified-id="What-is-the-output-of-the-following-code?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What is the output of the following code?</a></span></li><li><span><a href="#Doubly-Linked-List-has-more-efficient-methods-to-insert-and-delete-elements-than-singly-linked-lists." data-toc-modified-id="Doubly-Linked-List-has-more-efficient-methods-to-insert-and-delete-elements-than-singly-linked-lists.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Doubly Linked List has more efficient methods to insert and delete elements than singly linked lists.</a></span></li><li><span><a href="#The-prev-attribute-of-a-Node-object-is-supposed-to-point-to-which-of-the-following?" data-toc-modified-id="The-prev-attribute-of-a-Node-object-is-supposed-to-point-to-which-of-the-following?-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>The prev attribute of a Node object is supposed to point to which of the following?</a></span></li><li><span><a href="#What-is-the-output-of-the-following-code?" data-toc-modified-id="What-is-the-output-of-the-following-code?-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>What is the output of the following code?</a></span></li></ul></div>

# %% [markdown]
# # The code below is an implementation of the Node class for which of the following linked lists?#
#
# ```PYTHON
# class Node:
#     def __init__(self, data):
#         self.data = data
#         self.next = None
#         self.prev = None
# ```
#
# ANSWER IS :Doubly Linked Lists
#
# # What is the output of the following code? #
# ```python
# class DoublyLinkedList:
#     ...
#   def delete(self, key):
#           cur = self.head
#           while cur:
#               if cur.data == key:
#                   if cur.next:
#                       nxt = cur.next
#                       prev = cur.prev
#                       prev.next = nxt
#                       nxt.prev = prev
#                       cur.next = None
#                       cur.prev = None
#                       cur = None
#                       return
#                   else:
#                       prev = cur.prev
#                       prev.next = None
#                       cur.prev = None
#                       cur = None
#                       return
#               cur = cur.next
#
# dllist = DoublyLinkedList()
# dllist.append(1)
# dllist.append(2)
# dllist.append(3)
#
# dllist.delete(3)
# dllist.delete(1)
#
# dllist.print_list()
# ```
# THE ANSWER IS: ERROR
# Explanation:The delete method does not handle the case when we want to delete the head node.
#
# # Doubly Linked List has more efficient methods to insert and delete elements than singly linked lists. #
#
# THE ANSWER IS: False
#
# # The prev attribute of a Node object is supposed to point to which of the following? #
# **The previous node in the doubly linked list** IS RIGHT!
#
# The next attribute of the previous node in the doubly linked list   **WRONG ANSWER**
#
# The data attribute of the previous node in the doubly linked list   **WRONG ANSWER**
#
# The head node of the doubly linked list     **WRONG ANSWER**
#
#
# # What is the output of the following code? #
# ```PYTHON
# class DoublyLinkedList:
#      ...
#     def print_list(self):
#         cur = self.head
#         while cur.next:
#             cur = cur.next
#
#         while cur:
#             print(cur.data)
#             cur = cur.prev
#
#
# dllist = DoublyLinkedList()
# dllist.prepend(0)
# dllist.append(1)
# dllist.append(2)
# dllist.append(3)
# dllist.append(4)
# dllist.prepend(5)
#
# dllist.print_list()
# ```
#
# THE ANSWER IS :4 3 2 1 0 5
